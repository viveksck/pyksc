# %%
import pyksc

# %%
import pandas as pd

# %%
sdf = pd.DataFrame.from_csv('../Desktop/timeseries_nyu_source.csv')
sdf = sdf.dropna() 
print pd.isnull(sdf).any(1).nonzero()[0]

tdf = pd.DataFrame.from_csv('../Desktop/timeseries_nyu_dest.csv')
tdf = tdf.dropna() 
print pd.isnull(sdf).any(1).nonzero()[0]
#df = df[:1000]
# Out:
# []
# []

# %%
X = sdf[sdf.columns[1:]].values
X = np.ascontiguousarray(X)
X.shape
# Out:
# (9681, 106)

# %%
err = sdf.std().values
t_err = tdf.std().values

# %%
def errorfill(x, y, yerr, color=None, alpha_fill=0.3, ax=None):
    ax = ax if ax is not None else plt.gca()
    if color is None:
        color = ax._get_lines.color_cycle.next()
    if np.isscalar(yerr) or len(yerr) == len(y):
        ymin = y - yerr
        ymax = y + yerr
    elif len(yerr) == 2:
        ymin, ymax = yerr
    ax.plot(x, y, color=color)
    ax.fill_between(x, ymax, ymin, color=color, alpha=alpha_fill)
    ylim(0,1)

# %%
y_mean_sdf = sdf.mean(numeric_only=True).values
y_mean_tdf = tdf.mean(numeric_only=True).values

# %%
x = arange(1900, 2006, 1)

# %%
print len(y_mean_sdf), len(x)
# Out:
# 106 106

# %%
errorfill(x, y_mean_sdf, err,  color = 'red')
errorfill(x, y_mean_tdf, t_err,  color = 'red')
plot(x, sdf[sdf.word == 'gay'][sdf.columns[1:]].values[0], c = 'm')
plot(x, tdf[tdf.word == 'gay'][tdf.columns[1:]].values[0], c = 'm')

# %%
tdf[tdf[tdf.columns[1]] > 0.7]
# Out:
#               word      1900      1901      1902      1903      1904  \
# 321          phone  0.701232  0.690201  0.679230  0.668320  0.657473
# 660            guy  0.842288  0.824488  0.806959  0.789697  0.772700
# 883            dad  0.742992  0.723761  0.704978  0.686638  0.668734
# 1171       figured  0.815003  0.795344  0.776061  0.757151  0.738610
# 1809           bus  0.783414  0.771219  0.759010  0.746790  0.734563
# 1818        garage  0.725875  0.701536  0.677905  0.654973  0.632727
# 1997          urge  0.820994  0.815023  0.808864  0.802522  0.796001
# 2119    definitely  0.781722  0.772549  0.763414  0.754318  0.745259
# 2374      receiver  0.789089  0.760960  0.733600  0.706997  0.681141
# 3223        switch  0.723506  0.701627  0.680236  0.659328  0.638896
# 3586       plastic  0.736958  0.745663  0.753813  0.761416  0.768479
# 3701         sales  0.716985  0.711227  0.705587  0.700061  0.694643
# 3860    silhouette  0.701961  0.699750  0.697865  0.696294  0.695025
# ...
