# %%
import pyksc

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_csv('../Desktop/timeseries_source.csv')
df = df.dropna() 
print pd.isnull(df).any(1).nonzero()[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5f3945155c39> in <module>()
# ----> 1 df = pd.DataFrame.from_csv('../Desktop/timeseries_source.csv')
#       2 df = df.dropna()
#       3 print pd.isnull(df).any(1).nonzero()[0]
#
# NameError: name 'pd' is not defined

# %%
len(df[df.word=='fawn'].columns)
# Out:
# 207

# %%
X = df[df.columns[1:]].values
X = np.ascontiguousarray(X)

# %%
plot(df[df.word == 'kill'][df.columns[1:]].values[0])
ylim(0,1)
# Out:
# (0, 1)

# %%
from pyksc import ksc

# %%
X.shape
# Out:
# (15038, 206)

# %%
centroids, assignments, shifts, d = ksc.inc_ksc(X, 2)

# %%
plot(centroids[0])

# %%
plot(centroids[1])

# %%
plot(centroids[0], c='r')
plot(centroids[1], c='g')

# %%
print set(assignments)
# Out:
# set([0, 1])

# %%
np.where(assignments == 1)
# Out:
# (array([    0,     3,     4, ..., 15028, 15031, 15033]),)

# %%
plot(df.mean(numeric_only=True))
ylim(0,2)
# Out:
# (0, 2)

# %%
err = df.std().values

# %%
def errorfill(x, y, yerr, color=None, alpha_fill=0.3, ax=None):
    ax = ax if ax is not None else plt.gca()
    if color is None:
        color = ax._get_lines.color_cycle.next()
    if np.isscalar(yerr) or len(yerr) == len(y):
        ymin = y - yerr
        ymax = y + yerr
    elif len(yerr) == 2:
        ymin, ymax = yerr
    ax.plot(x, y, color=color)
    ax.fill_between(x, ymax, ymin, color=color, alpha=alpha_fill)
    ylim(0,1)

# %%
y_mean = df.mean(numeric_only=True).values

# %%
x = arange(1800, 2005 + 1, 1)

# %%
print len(y_mean), len(x)
# Out:
# 206 206

# %%
errorfill(x, y_mean, err,  color = 'red')
plot(x, df[df.word == 'gay'][df.columns[1:]].values[0], c ='y')
plot(x, df[df.word == 'queen'][df.columns[1:]].values[0], c = 'g')
plot(x, df[df.word == 'mouse'][df.columns[1:]].values[0], c = 'm')
plot(x, df[df.word == 'file'][df.columns[1:]].values[0], c= 'b')
plot(x, df[df.word == 'god'][df.columns[1:]].values[0], c= 'c')
plot(x, df[df.word == 'walk'][df.columns[1:]].values[0], c= 'k')
plot(x, df[df.word == 'dirty'][df.columns[1:]].values[0], c= 'r')

# %%
# Out:
# [ 0.00112168  0.0011133   0.00110528  0.00109761  0.00109028  0.00108327
#   0.00107658  0.0010702   0.00106411  0.00105831  0.00105278  0.00104751
#   0.0010425   0.00103774  0.0010332   0.00102889  0.0010248   0.00102091
#   0.00101721  0.0010137   0.00101037  0.0010072   0.0010042   0.00100135
#   0.00099864  0.00099606  0.00099362  0.00099129  0.00098909  0.00098698
#   0.00098498  0.00098308  0.00098126  0.00097952  0.00097786  0.00097628
#   0.00097476  0.0009733   0.0009719   0.00097056  0.00096926  0.00096801
#   0.0009668   0.00096563  0.00096449  0.00096338  0.0009623   0.00096125
#   0.00096022  0.00095922  0.00095823  0.00095726  0.0009563   0.00095535
#   0.00095442  0.0009535   0.00095258  0.00095167  0.00095077  0.00094987
#   0.00094898  0.00094808  0.00094719  0.00094631  0.00094542  0.00094453
#   0.00094364  0.00094276  0.00094187  0.00094097  0.00094008  0.00093919
#   0.00093829  0.00093739  0.00093649  0.00093558  0.00093468  0.00093377
# ...

# %%
df[df.word == 'gay']
# Out:
#       word      1800      1801      1802      1803      1804      1805  \
# 18385  gay  0.739385  0.734017  0.728823  0.723801  0.718949  0.714264
#
#            1806      1807      1808    ...        1996      1997      1998  \
# 18385  0.709745  0.705389  0.701194    ...     0.38554  0.373654  0.361526
#
#            1999      2000      2001      2002      2003      2004      2005
# 18385  0.349153  0.336533  0.323664  0.310544  0.297171  0.283542  0.269656
#
# [1 rows x 207 columns]

# %%
assignments[9971]
# Out:
# 2

# %%
df =df.reindex()
df.index
# Out:
# Int64Index([3, 4, 5, 6, 10, 13, 16, 18, 19, 20, 23, 24, 27, 28, 29, 30, 31, 32, 33, 36, 39, 47, 48, 49, 50, 51, 53, 54, 58, 59, 60, 61, 63, 65, 66, 68, 70, 71, 72, 73, 74, 76, 77, 80, 81, 84, 85, 89, 90, 91, 92, 93, 95, 96, 97, 98, 99, 101, 105, 108, 109, 110, 112, 113, 115, 117, 118, 119, 121, 122, 123, 124, 126, 129, 130, 131, 133, 135, 137, 138, 140, 141, 143, 145, 148, 149, 153, 156, 157, 161, 162, 163, 164, 166, 167, 169, 171, 172, 173, 175, ...], dtype='int64')

# %%
df = df.reindex(index=arange(0, len(df)))
df.iloc[:, :]
# Out:
#                 word      1800      1801      1802      1803      1804  \
# 0                NaN       NaN       NaN       NaN       NaN       NaN
# 1                NaN       NaN       NaN       NaN       NaN       NaN
# 2                NaN       NaN       NaN       NaN       NaN       NaN
# 3              woods  0.483930  0.479486  0.475124  0.470843  0.466644
# 4            clotted  0.424109  0.422689  0.421317  0.419994  0.418717
# 5            spiders  0.698303  0.694167  0.690127  0.686183  0.682333
# 6            hanging  0.633905  0.628842  0.623858  0.618953  0.614127
# 7                NaN       NaN       NaN       NaN       NaN       NaN
# 8                NaN       NaN       NaN       NaN       NaN       NaN
# 9                NaN       NaN       NaN       NaN       NaN       NaN
# 10             scold  0.416313  0.412308  0.408367  0.404492  0.400680
# 11               NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
len(np.where(assignments == 1)[0][:2)
# Out:
#   File "<ipython-input-310-60cd03420412>", line 1
#     len(np.where(assignments == 1)[0][:2)
#                                         ^
# SyntaxError: invalid syntax

# %%
df[[3,5,6]]
# Out:
#            1802      1804      1805
# 3      0.475124  0.466644  0.462526
# 4      0.421317  0.418717  0.417488
# 5      0.690127  0.682333  0.678578
# 6      0.623858  0.614127  0.609378
# 10     0.408367  0.400680  0.396932
# 13     0.800311  0.802527  0.803563
# 16     0.339397  0.336963  0.335803
# 18     0.705036  0.687008  0.678268
# 19     0.510089  0.501886  0.497905
# 20     0.679551  0.666270  0.659838
# 23     0.620951  0.610391  0.605249
# 24     0.503271  0.496972  0.493914
# 27     0.369363  0.366955  0.365793
# 28     0.466431  0.461810  0.459581
# 29     0.673257  0.669808  0.668181
# 30     0.513278  0.503586  0.498906
# 31     0.566961  0.556748  0.551801
# 32     0.779715  0.770147  0.765547
# 33     0.722676  0.712824  0.708018
# 36     0.542599  0.533179  0.528648
# 39     0.601183  0.593451  0.589746
# 47     0.670748  0.663589  0.660126
# 48     0.445765  0.445765  0.445765
# 49     0.545334  0.540497  0.538150
# 50     0.523895  0.513464  0.508431
# ...

# %%
np.where(df.index == 12155)
# Out:
# (array([6625]),)

# %%
df[df.word == 'god']
# Out:
#       word      1800      1801      1802      1803      1804      1805  \
# 12155  god  0.455012  0.453374  0.451777  0.450218  0.448698  0.447216
#
#            1806      1807      1808    ...         1996      1997      1998  \
# 12155  0.445772  0.444365  0.442994    ...     0.269353  0.265863  0.262314
#
#            1999      2000      2001      2002      2003      2004      2005
# 12155  0.258705  0.255037  0.251307  0.247517  0.243665  0.239751  0.235774
#
# [1 rows x 207 columns]

# %%
print assignments[6625]
# Out:
# 1

# %%
8695+6343
# Out:
# 15038
