# %%
import pyksc

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_csv('../synthetic_timeseries/10/output/timeseries_linear_source.csv')
df = df.dropna() 
print pd.isnull(df).any(1).nonzero()[0]
# Out:
# []

# %%
df
# Out:
#            word             0        10        20        30        40  \
# 0      migrated -2.220446e-16  0.009042  0.013705  0.010459  0.019343
# 1         being  0.000000e+00  0.008502  0.012675  0.009563  0.007339
# 2          when  1.110223e-16  0.009955  0.015202  0.015134  0.019230
# 3          over -2.220446e-16  0.003977  0.010592  0.012739  0.012012
# 4        yellow -2.220446e-16  0.010991  0.023374  0.026757  0.012621
# 5       through  0.000000e+00  0.011752  0.012536  0.019424  0.013870
# 6      migrates  1.110223e-16  0.016486  0.008192  0.010257  0.014416
# 7        corner  0.000000e+00  0.003225  0.003681  0.003592  0.004408
# 8           its  0.000000e+00  0.015308  0.012124  0.022706  0.018052
# 9         whose -2.220446e-16  0.016100  0.021843  0.026658  0.015355
# 10    migrating  0.000000e+00  0.010546  0.008387  0.007985  0.012201
# 11          had  0.000000e+00  0.007966  0.013537  0.013315  0.009256
# ...

# %%
err = df.std().values

# %%
def errorfill(x, y, yerr, color=None, alpha_fill=0.3, ax=None):
    ax = ax if ax is not None else plt.gca()
    if color is None:
        color = ax._get_lines.color_cycle.next()
    if np.isscalar(yerr) or len(yerr) == len(y):
        ymin = y - yerr
        ymax = y + yerr
    elif len(yerr) == 2:
        ymin, ymax = yerr
    ax.plot(x, y, color=color)
    ax.fill_between(x, ymax, ymin, color=color, alpha=alpha_fill)

# %%
y_mean = df.mean(numeric_only=True).values

# %%
x = arange(0, 110, 10)

# %%
print len(y_mean), len(x)
# Out:
# 11 11

# %%
errorfill(x, y_mean, err,  color = 'red')
plot(x, df[df.word == 'gay'][df.columns[1:]].values[0], c = 'm')
plot(x, df[df.word == 'had'][df.columns[1:]].values[0], c = 'y')
plot(x, df[df.word == 'hot'][df.columns[1:]].values[0], c = 'g')
