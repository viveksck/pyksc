# %%
import pyksc

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_csv('../synthetic_timeseries/90/output/timeseries_linear_source.csv')
df = df.dropna() 
print pd.isnull(df).any(1).nonzero()[0]
# Out:
# []

# %%
df
# Out:
#            word             0        10        20        30        40  \
# 0      migrated  0.000000e+00  0.009964  0.006437  0.011535  0.009115
# 1     currently  0.000000e+00  0.004932  0.005521  0.007025  0.004683
# 2         being -2.220446e-16  0.006076  0.013032  0.012172  0.014053
# 3          over  2.220446e-16  0.003888  0.003179  0.005036  0.003661
# 4        yellow  1.110223e-16  0.007266  0.006332  0.005326  0.002327
# 5       through  0.000000e+00  0.006287  0.008620  0.005683  0.005984
# 6      migrates  0.000000e+00  0.008754  0.004549  0.003675  0.004056
# 7        corner -2.220446e-16  0.003962  0.006894  0.002089  0.004560
# 8      plodding  0.000000e+00  0.007214  0.005555  0.002902  0.005679
# 9         whose  0.000000e+00  0.004764  0.011458  0.005087  0.012849
# 10     angolian  0.000000e+00  0.004831  0.015134  0.008658  0.015036
# 11          had  2.220446e-16  0.006320  0.006958  0.006409  0.005697
# ...

# %%
err = df.std().values

# %%
def errorfill(x, y, yerr, color=None, alpha_fill=0.3, ax=None):
    ax = ax if ax is not None else plt.gca()
    if color is None:
        color = ax._get_lines.color_cycle.next()
    if np.isscalar(yerr) or len(yerr) == len(y):
        ymin = y - yerr
        ymax = y + yerr
    elif len(yerr) == 2:
        ymin, ymax = yerr
    ax.plot(x, y, color=color)
    ax.fill_between(x, ymax, ymin, color=color, alpha=alpha_fill)

# %%
y_mean = df.mean(numeric_only=True).values

# %%
x = arange(0, 110, 10)

# %%
print len(y_mean), len(x)
# Out:
# 11 11

# %%
def interploate(y):
    from scipy.interpolate import UnivariateSpline, interp1d
    f =  interp1d(x, y)
    ix = np.arange(0, 101, 1)
    yi = f(ix)
    print len(yi)
    return yi

# %%
errorfill(x, y_mean, err,  color = 'red')
plot(np.arange(0, 101, 1), interploate(df[df.word == 'gay'][df.columns[1:]].values[0]), c = 'm')
plot(np.arange(0, 101, 1), interploate(df[df.word == 'had'][df.columns[1:]].values[0]), c = 'y')
plot(np.arange(0, 101, 1), interploate(df[df.word == 'fruit'][df.columns[1:]].values[0]), c = 'g')
# Out:
# 101
# 101
# 101
